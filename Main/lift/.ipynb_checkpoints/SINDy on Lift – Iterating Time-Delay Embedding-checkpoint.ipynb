# %% [markdown]
# ### Introduction
# This notebook enhances the previous analysis of coefficients of lift and drag in cylinder vortex shedding by now varying $\tau$, the degree of time-delay embedding, thereby producing a range of sparse models.
#
# We again load the data and time-delay embed our chosen signal; we then fit a model with a specified $\lambda$, the parameter that controls sparsity. We repeat this process for a range of values of $\tau$.

# %%
###  Import modules

import numpy as np
import matplotlib.pyplot as plt
import json

import warnings
warnings.filterwarnings("ignore")


###  Load the analysis settings and parameters

#  Load the configuration file with all settings
with open('Lift-config.json', 'r') as f:
    config = json.load(f)

#  Read out and import all variables
for key, value in config.items():  print(f"{key}: {value}")
globals().update(config)
# Out:
# Re: 50
# l_d_flag: lift
# t_trm_1: 25000
# t_trm_2: 50000
# TDE_or_ddt: TDE
# TD_Embed: 3
# threshold: 0
# poly_order: 3
# diff_order: 2
# should_normalize: 1
# iterations: 31

# %%
# %%javascript
# require("notebook/js/notebook").Notebook.prototype.scroll_to_bottom = function () {}

# %%
###  Initiate and run SINDy, iteratively for varying sparisty

from runSINDy_Iter_TDE import fnc_runSINDy_Iter_TDE
save_dir , model , TDE_vec , Coefs_u1 , Coefs_u2 , NRMSE_1 , NRMSE_2 , NRMSE_sys = \
fnc_runSINDy_Iter_TDE()
# Out:
# Iterating from tau = 0 to tau = 3
#
# Iteration  =  0  /  30  |  tau  =  0.0
# Iteration  =  3  /  30  |  tau  =  0.30000000000000004
# Iteration  =  6  /  30  |  tau  =  0.6000000000000001
# Iteration  =  9  /  30  |  tau  =  0.9
# Iteration  =  12  /  30  |  tau  =  1.2000000000000002
# Iteration  =  15  /  30  |  tau  =  1.5
# Iteration  =  18  /  30  |  tau  =  1.8
# Iteration  =  21  /  30  |  tau  =  2.1
# Iteration  =  24  /  30  |  tau  =  2.4000000000000004
# Iteration  =  27  /  30  |  tau  =  2.7
# Iteration  =  30  /  30  |  tau  =  3.0

# %%
###  Plot NRMSE of the system vs. sparsity

plt.figure()
plt.plot( TDE_vec , NRMSE_sys  )
plt.xlabel(r'$\tau$' , fontsize=16)
plt.ylabel('NRMSE' , fontsize=16)
ttl_str = 'NRMSE of System vs. Time-Delay Embedding' + '\nRe = ' + str(Re)
plt.title(ttl_str , fontsize = 16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.savefig(save_dir+'Plots/'+'NRMSE_system.png')
plt.show()


###  Plot NRMSE of each signal vs. sparsity

plt.figure()
plt.plot( TDE_vec , NRMSE_1 , label=r'$\omega$' )
plt.plot( TDE_vec , NRMSE_2 , label=r'$\eta$  ' )
plt.xlabel(r'$\tau$' , fontsize=16)
plt.ylabel('NRMSE' , fontsize=16)
ttl_str = 'NRMSE of System vs. Time-Delay Embedding' + '\nRe = ' + str(Re)
plt.title(ttl_str , fontsize = 16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=16)
plt.savefig(save_dir+'Plots/'+'NRMSE_signals.png')
plt.show()

# %%
###  Plot the coefficients of the system vs. sparsity

# model.get_feature_names()


###  Plot constant term vs. sparsity

plt.figure()
plt.plot( TDE_vec , Coefs_u1[:,0] , label='u_1 1' )
plt.plot( TDE_vec , Coefs_u2[:,0] , label='u_2 1' )
plt.xlabel(r'$\tau$' , fontsize=16)
plt.ylabel('Coefficient' , fontsize=16)
ttl_str = 'Constant Term vs. Time-Delay Embedding' + '\nRe = ' + str(Re)
plt.title(ttl_str , fontsize = 16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend()
plt.savefig(save_dir+'Plots/'+'Coefs_Ord_0.png')
plt.show()


###  Plot linear term coefficients vs. sparsity

plt.figure()

plt.plot( TDE_vec , Coefs_u1[:,1] , label='u_1 (x)' )
plt.plot( TDE_vec , Coefs_u1[:,2] , label='u_1 (y)' )

plt.plot( TDE_vec , Coefs_u2[:,1] , label='u_2 (x)' )
plt.plot( TDE_vec , Coefs_u2[:,2] , label='u_2 (y)' )

plt.xlabel(r'$\tau$' , fontsize=16)
plt.ylabel('Coefficient' , fontsize=16)
ttl_str = 'Linear Term Coefficients vs. Time-Delay Embedding' + '\nRe = ' + str(Re)
plt.title(ttl_str , fontsize = 16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend()
plt.savefig(save_dir+'Plots/'+'Coefs_Ord_1.png')
plt.show()


###  Plot quadratic term coefficients vs. sparsity

plt.figure()

plt.plot( TDE_vec , Coefs_u1[:,3] , label='u_1 (x^2)' )
plt.plot( TDE_vec , Coefs_u1[:,4] , label='u_1 (xy)' )
plt.plot( TDE_vec , Coefs_u1[:,5] , label='u_1 (y^2)' )

plt.plot( TDE_vec , Coefs_u2[:,3] , label='u_2 (x^2)' )
plt.plot( TDE_vec , Coefs_u2[:,4] , label='u_2 (xy)' )
plt.plot( TDE_vec , Coefs_u2[:,5] , label='u_2 (y^2)' )

plt.xlabel(r'$\tau$' , fontsize=16)
plt.ylabel('Coefficient' , fontsize=16)
ttl_str = 'Quadratic Term Coefficients vs. Time-Delay Embedding' + '\nRe = ' + str(Re)
plt.title(ttl_str , fontsize = 16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend()
plt.savefig(save_dir+'Plots/'+'Coefs_Ord_2.png')
plt.show()


###  Plot cubic term coefficients vs. sparsity

plt.figure()

plt.plot( TDE_vec , Coefs_u1[:,6] , label='u_1 (x^3)' )
plt.plot( TDE_vec , Coefs_u1[:,7] , label='u_1 (x^2y)' )
plt.plot( TDE_vec , Coefs_u1[:,8] , label='u_1 (xy^2)' )
plt.plot( TDE_vec , Coefs_u1[:,9] , label='u_1 (y^3)' )

plt.plot( TDE_vec , Coefs_u2[:,6] , label='u_2 (x^3)' )
plt.plot( TDE_vec , Coefs_u2[:,7] , label='u_2 (x^2y)' )
plt.plot( TDE_vec , Coefs_u2[:,8] , label='u_2 (xy^2)' )
plt.plot( TDE_vec , Coefs_u1[:,9] , label='u_1 (y^3)' )

plt.xlabel(r'$\tau$' , fontsize=16)
plt.ylabel('Coefficient' , fontsize=16)
ttl_str = 'Cubic Term Coefficients vs. Time-Delay Embedding' + '\nRe = ' + str(Re)
plt.title(ttl_str , fontsize = 16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc='lower center')
plt.savefig(save_dir+'Plots/'+'Coefs_Ord_3.png')
plt.show()
